# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import poisson
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import random

# %% [markdown]
# # 1. DATA 불러오기

# %%
doosan_df1 = pd.read_csv('두산 타자 종합 data.csv', encoding="cp949")
kt_df1 = pd.read_csv('KT 타자 종합 data.csv', encoding="cp949")

doosan_df2 = pd.read_csv('두산 타자 아웃카운트별 data.csv', encoding="cp949")
kt_df2 = pd.read_csv('KT 타자 아웃카운트별 data.csv', encoding="cp949")

doosan_df3 = pd.read_csv('두산 타자 주자 위치별 data.csv', encoding="cp949")
kt_df3 = pd.read_csv('KT 타자 주자 위치별 data.csv', encoding="cp949")

doosan_df4 = pd.read_csv('두산 타자 카운트별 data.csv', encoding="cp949")
kt_df4 = pd.read_csv('KT 타자 카운트별 data.csv', encoding="cp949")

doosan_df5 = pd.read_csv('두산 투수 상대전적 data.csv', encoding="cp949")
kt_df5 = pd.read_csv('KT 투수 상대전적 data.csv', encoding="cp949")

# %%
doosan_df1
# Out:
#    타자 정보     타율  안타  2루타  3루타  홈런  타점  득점  희생번트  희생플라이  볼넷  삼진    장타율    출루율  \
# 0    정수빈  0.271  42    5    0   2  14  28     2      2  23  15  0.342  0.375
# 1    케이브  0.319  45    7    1   3  22  22     0      3  10  31  0.447  0.361
# 2    양의지  0.329  47    9    0   5  29  20     0      2  21  21  0.497  0.417
# 3    김재환  0.255  35    4    1   5  24  19     0      0  17  34  0.409  0.346
# 4    양석환  0.277  44   10    0   5  22  21     0      3  13  45  0.434  0.341
# 5    강승호  0.224  35   10    2   3  16  23     0      1  14  52  0.372  0.303
# 6    오명진  0.253  23    5    2   1  16  13     0      0   9  20  0.385  0.327
# 7    김인태  0.283  17    4    0   1   8   6     0      0  13  14  0.400  0.411
# 8    박준영  0.227  25    8    0   1  10   9     1      1  10  32  0.327  0.306
# 9    김기연  0.305  18    3    0   1  11   7     2      1   6  14  0.407  0.364
# 10   임종성  0.227   5    1    0   0   2   1     0      0   0   4  0.273  0.227
#
#       OPS
# 0   0.717
# 1   0.808
# 2   0.914
# 3   0.755
# 4   0.775
# 5   0.675
# 6   0.712
# 7   0.811
# 8   0.633
# 9   0.771
# 10  0.500

# %%
kt_df1
# Out:
#    타자 정보     타율  안타  2루타  3루타  홈런  타점  득점  희생번트  희생플라이  볼넷  삼진    장타율    출루율  \
# 0    로하스  0.237  37    8    0   6  18  25     0      2  32  40  0.404  0.366
# 1    강백호  0.227  29    6    0   6  16  12     0      0  12  26  0.414  0.298
# 2    허경민  0.301  31    2    0   1   8   9     0      1  11  12  0.350  0.371
# 3    안현민  0.370  20    4    1   6  17  10     0      0   4  10  0.815  0.433
# 4    장성우  0.208  27    4    0   4  19  12     1      4  21  34  0.331  0.310
# 5    김민혁  0.329  54    6    1   0  11  21     0      1   6  14  0.378  0.358
# 6    황재균  0.256  34    5    0   1  13  13     0      1  14  30  0.316  0.329
# 7    배정대  0.184  21    5    2   1  12   6     4      2   5  33  0.289  0.234
# 8    김상수  0.206  12    3    0   1   3   7     0      0  14   6  0.302  0.351
# 9    문상철  0.227  22    3    1   1   5   7     0      1  10  24  0.309  0.303
# 10   권동진  0.317  26    3    1   0   7  10     2      1  11  26  0.378  0.394
#
#       OPS
# 0   0.770
# 1   0.712
# 2   0.721
# 3   1.248
# 4   0.641
# 5   0.736
# 6   0.645
# 7   0.523
# 8   0.653
# 9   0.602
# 10  0.772

# %%
doosan_df2
# Out:
#    아웃카운트에 따른 타율  0 OUT  1 OUT  2 OUT
# 0           정수빈  0.297  0.222  0.267
# 1           케이브  0.302  0.388  0.256
# 2           양의지  0.341  0.255  0.392
# 3           김재환  0.250  0.156  0.354
# 4           양석환  0.311  0.273  0.254
# 5           강승호  0.232  0.283  0.149
# 6           오명진  0.226  0.400  0.133
# 7           김인태  0.222  0.238  0.381
# 8           박준영  0.360  0.233  0.143
# 9           김기연  0.238  0.286  0.412
# 10          임종성  0.167  0.333  0.200

# %%
kt_df2
# Out:
#    아웃카운트에 따른 타율  0 OUT  1 OUT  2 OUT
# 0           로하스  0.221  0.255  0.243
# 1           강백호  0.268  0.195  0.217
# 2           허경민  0.259  0.268  0.371
# 3           안현민  0.350  0.313  0.444
# 4           장성우  0.143  0.250  0.245
# 5           김민혁  0.288  0.345  0.360
# 6           황재균  0.227  0.304  0.212
# 7           배정대  0.118  0.171  0.256
# 8           김상수  0.217  0.333  0.120
# 9           문상철  0.200  0.294  0.184
# 10          권동진  0.519  0.194  0.250

# %% [markdown]
# ## NaN 값을 타자의 1루~만루 타율 값의 평균으로 넣어주기

# %%
doosan_df3
# Out:
#    주자 위치에 따른 타율     1루     2루     3루  1루,2루  1루,3루  2루,3루     만루
# 0           정수빈  0.393  0.364  0.167  0.167  0.000  0.500  0.000
# 1           케이브  0.290  0.429  0.000  0.286  0.500  1.000  0.000
# 2           양의지  0.393  0.389  0.500  0.385  0.500  0.500  0.000
# 3           김재환  0.324  0.500  0.000  0.385  0.500  0.000  0.000
# 4           양석환  0.206  0.313  0.000  0.000  0.400  0.600  0.250
# 5           강승호  0.235  0.000  0.429  0.286  0.250  0.000  0.200
# 6           오명진  0.200  0.400  0.333  0.000  0.333  0.000  0.667
# 7           김인태  0.250  0.500  0.500  0.200  0.000  0.333  0.500
# 8           박준영  0.174  0.200  0.000  0.333  0.000  0.333  0.000
# 9           김기연  0.583  0.000  0.000  0.400    NaN  0.333  1.000
# 10          임종성  0.500  0.333    NaN  0.500  0.000  0.000    NaN

# %%
cols_to_fill = ["1루", "2루", "3루", "1루,2루", "1루,3루", "2루,3루", "만루"]
doosan_df3[cols_to_fill] = doosan_df3[cols_to_fill].apply(lambda row: row.fillna(row.mean()), axis=1)
doosan_df3
# Out:
#    주자 위치에 따른 타율     1루     2루      3루  1루,2루  1루,3루  2루,3루      만루
# 0           정수빈  0.393  0.364  0.1670  0.167  0.000  0.500  0.0000
# 1           케이브  0.290  0.429  0.0000  0.286  0.500  1.000  0.0000
# 2           양의지  0.393  0.389  0.5000  0.385  0.500  0.500  0.0000
# 3           김재환  0.324  0.500  0.0000  0.385  0.500  0.000  0.0000
# 4           양석환  0.206  0.313  0.0000  0.000  0.400  0.600  0.2500
# 5           강승호  0.235  0.000  0.4290  0.286  0.250  0.000  0.2000
# 6           오명진  0.200  0.400  0.3330  0.000  0.333  0.000  0.6670
# 7           김인태  0.250  0.500  0.5000  0.200  0.000  0.333  0.5000
# 8           박준영  0.174  0.200  0.0000  0.333  0.000  0.333  0.0000
# 9           김기연  0.583  0.000  0.0000  0.400  0.386  0.333  1.0000
# 10          임종성  0.500  0.333  0.2666  0.500  0.000  0.000  0.2666

# %%
kt_df3
# Out:
#    주자 위치에 따른 타율     1루     2루     3루  1루,2루  1루,3루  2루,3루     만루
# 0           로하스  0.200  0.333  0.200  0.143   0.00  0.000  1.000
# 1           강백호  0.237  0.300  0.400  0.100   0.25  0.000  0.000
# 2           허경민  0.333  0.000  0.400  0.125   0.50  0.250    NaN
# 3           안현민  0.455  0.333  0.667  0.500   0.00  0.000  0.500
# 4           장성우  0.250  0.333  0.000  0.100   0.25  0.000  0.400
# 5           김민혁  0.267  0.143  0.333  0.364   0.40  0.000  0.333
# 6           황재균  0.323  0.000  0.667  0.455   1.00  0.000  0.500
# 7           배정대  0.217  0.125  0.667  0.231    NaN  0.333  0.000
# 8           김상수  0.200  0.000  0.500  0.000   1.00    NaN  0.000
# 9           문상철  0.143  0.000  0.500  0.222   0.00  0.000  0.000
# 10          권동진  0.333  0.000  0.500  0.500   0.25  1.000  0.000

# %%
cols_to_fill = ["1루", "2루", "3루", "1루,2루", "1루,3루", "2루,3루", "만루"]
kt_df3[cols_to_fill] = kt_df3[cols_to_fill].apply(lambda row: row.fillna(row.mean()), axis=1)
kt_df3
# Out:
#    주자 위치에 따른 타율     1루     2루     3루  1루,2루     1루,3루     2루,3루     만루
# 0           로하스  0.200  0.333  0.200  0.143  0.000000  0.000000  1.000
# 1           강백호  0.237  0.300  0.400  0.100  0.250000  0.000000  0.000
# 2           허경민  0.333  0.000  0.400  0.125  0.500000  0.250000  0.268
# 3           안현민  0.455  0.333  0.667  0.500  0.000000  0.000000  0.500
# 4           장성우  0.250  0.333  0.000  0.100  0.250000  0.000000  0.400
# 5           김민혁  0.267  0.143  0.333  0.364  0.400000  0.000000  0.333
# 6           황재균  0.323  0.000  0.667  0.455  1.000000  0.000000  0.500
# 7           배정대  0.217  0.125  0.667  0.231  0.262167  0.333000  0.000
# 8           김상수  0.200  0.000  0.500  0.000  1.000000  0.283333  0.000
# 9           문상철  0.143  0.000  0.500  0.222  0.000000  0.000000  0.000
# 10          권동진  0.333  0.000  0.500  0.500  0.250000  1.000000  0.000

# %% [markdown]
# ## NaN 값을 각 행의 평균 값으로 넣어주기 (예를 들어 임종성 선수의 1S 1B 카운트의 NaN 값을 그 카운트의 전체 평균값으로 넣어주기)

# %%
doosan_df4
# Out:
#    카운트에 따른 타자 타율  0S 0B    1S      2S  1S 1B  1S 2B  1S 3B  2S 1B  2S 2B  \
# 0            정수빈  0.417  0.167  0.214  0.300  0.333  0.857  0.200  0.188
# 1            케이브  0.533  0.400  0.083  0.385  0.167  1.000  0.250  0.333
# 2            양의지  0.381  0.583  0.364  0.333  0.333  0.500  0.222  0.240
# 3            김재환  0.450  0.385  0.231  0.333  0.167  0.250  0.083  0.042
# 4            양석환  0.400  0.385  0.250  0.429  0.286  0.333  0.156  0.281
# 5            강승호  0.200  0.385  0.143  0.429  0.500  0.500  0.077  0.103
# 6            오명진  0.571  0.167  0.167  0.200  0.000    NaN  0.077  0.222
# 7            김인태  0.429  0.600  0.000  0.000  0.000  1.000  0.250  0.375
# 8            박준영  0.250  0.167  0.250  0.429  0.167  0.000  0.080  0.316
# 9            김기연  0.571  0.200  0.143  0.400  0.400  1.000  0.000  0.333
# 10           임종성  0.250  0.000  0.000    NaN  0.500    NaN  0.000  0.600
#
#     2S 3B     1B     2B  3B
# 0   0.214  0.500  0.000 NaN
# 1   0.167  0.313  0.429 NaN
# 2   0.308  0.214  0.667 NaN
# 3   0.375  0.571  0.333 NaN
# 4   0.278  0.143  0.000 NaN
# 5   0.111  0.583  0.000 NaN
# 6   0.400  0.273  0.000 NaN
# 7   0.667  0.000  1.000 NaN
# 8   0.375  0.000  0.500 NaN
# 9   0.667  0.200  0.500 NaN
# 10  0.000  0.000    NaN NaN

# %% [markdown]
# ## 여기서 1S는 제거했는데, 주피터 노트북의 오류인지는 잘 모르겠지만 1S column을 인식하지 못하는 상황이라 빼고 입력했습니다. 아마 다른 data들도 1s에서 오류가 발생하면 빼고 진행하시면 됩니다!

# %%
count_cols = ['0S 0B', '2S', '1S 1B', '1S 2B', '1S 3B', 
              '2S 1B', '2S 2B', '2S 3B', '1B', '2B', '3B']

doosan_df4[count_cols] = doosan_df4[count_cols].fillna(doosan_df4[count_cols].mean())
doosan_df4
# Out:
#    카운트에 따른 타자 타율  0S 0B    1S      2S   1S 1B  1S 2B     1S 3B  2S 1B  2S 2B  \
# 0            정수빈  0.417  0.167  0.214  0.3000  0.333  0.857000  0.200  0.188
# 1            케이브  0.533  0.400  0.083  0.3850  0.167  1.000000  0.250  0.333
# 2            양의지  0.381  0.583  0.364  0.3330  0.333  0.500000  0.222  0.240
# 3            김재환  0.450  0.385  0.231  0.3330  0.167  0.250000  0.083  0.042
# 4            양석환  0.400  0.385  0.250  0.4290  0.286  0.333000  0.156  0.281
# 5            강승호  0.200  0.385  0.143  0.4290  0.500  0.500000  0.077  0.103
# 6            오명진  0.571  0.167  0.167  0.2000  0.000  0.604444  0.077  0.222
# 7            김인태  0.429  0.600  0.000  0.0000  0.000  1.000000  0.250  0.375
# 8            박준영  0.250  0.167  0.250  0.4290  0.167  0.000000  0.080  0.316
# 9            김기연  0.571  0.200  0.143  0.4000  0.400  1.000000  0.000  0.333
# 10           임종성  0.250  0.000  0.000  0.3238  0.500  0.604444  0.000  0.600
#
#     2S 3B     1B      2B  3B
# 0   0.214  0.500  0.0000 NaN
# 1   0.167  0.313  0.4290 NaN
# 2   0.308  0.214  0.6670 NaN
# 3   0.375  0.571  0.3330 NaN
# 4   0.278  0.143  0.0000 NaN
# 5   0.111  0.583  0.0000 NaN
# 6   0.400  0.273  0.0000 NaN
# 7   0.667  0.000  1.0000 NaN
# 8   0.375  0.000  0.5000 NaN
# 9   0.667  0.200  0.5000 NaN
# 10  0.000  0.000  0.3429 NaN

# %%
kt_df4
# Out:
#    카운트에 따른 타자 타율  0S 0B    1S      2S  1S 1B  1S 2B  1S 3B  2S 1B  2S 2B  \
# 0            로하스  0.400  0.211  0.000  0.714  0.600  0.000  0.172  0.231
# 1            강백호  0.273  0.222  0.158  0.267  0.286  0.500  0.056  0.167
# 2            허경민  0.200  0.333  0.158  0.300  0.500  0.200  0.375  0.400
# 3            안현민  0.500  0.286  0.333  0.300  1.000  0.400  0.400  0.000
# 4            장성우  0.300  0.429  0.125  0.286  0.333  0.250  0.120  0.267
# 5            김민혁  0.227  0.467  0.143  0.300  0.438  0.286  0.360  0.400
# 6            황재균  0.308  0.300  0.154  0.500  0.417  0.000  0.214  0.182
# 7            배정대  0.300  0.558  0.000  0.333  0.429  0.000  0.059  0.053
# 8            김상수  0.000  0.167  0.000  0.077  0.500  0.000  0.200  0.250
# 9            문상철  0.409  0.250  0.357  0.333  0.125  0.333  0.077  0.167
# 10           권동진  0.400  0.429  0.182  0.200  0.500  0.500  0.385  0.333
#
#     2S 3B     1B     2B   3B
# 0   0.250  0.250  0.400  0.0
# 1   0.188  0.364  0.600  NaN
# 2   0.333    NaN    NaN  NaN
# 3   0.333  0.667  0.667  NaN
# 4   0.118  0.133  0.000  NaN
# 5   0.182  0.500  0.200  NaN
# 6   0.286  0.500  0.000  NaN
# 7   0.200  0.167  1.000  NaN
# 8   0.571  0.600  0.000  NaN
# 9   0.091  0.100  0.000  NaN
# 10  0.286  0.167    NaN  NaN

# %%
count_cols = ['0S 0B', '2S', '1S 1B', '1S 2B', '1S 3B', 
              '2S 1B', '2S 2B', '2S 3B', '1B', '2B', '3B']

kt_df4[count_cols] = kt_df4[count_cols].fillna(kt_df4[count_cols].mean())
kt_df4
# Out:
#    카운트에 따른 타자 타율  0S 0B    1S      2S  1S 1B  1S 2B  1S 3B  2S 1B  2S 2B  \
# 0            로하스  0.400  0.211  0.000  0.714  0.600  0.000  0.172  0.231
# 1            강백호  0.273  0.222  0.158  0.267  0.286  0.500  0.056  0.167
# 2            허경민  0.200  0.333  0.158  0.300  0.500  0.200  0.375  0.400
# 3            안현민  0.500  0.286  0.333  0.300  1.000  0.400  0.400  0.000
# 4            장성우  0.300  0.429  0.125  0.286  0.333  0.250  0.120  0.267
# 5            김민혁  0.227  0.467  0.143  0.300  0.438  0.286  0.360  0.400
# 6            황재균  0.308  0.300  0.154  0.500  0.417  0.000  0.214  0.182
# 7            배정대  0.300  0.558  0.000  0.333  0.429  0.000  0.059  0.053
# 8            김상수  0.000  0.167  0.000  0.077  0.500  0.000  0.200  0.250
# 9            문상철  0.409  0.250  0.357  0.333  0.125  0.333  0.077  0.167
# 10           권동진  0.400  0.429  0.182  0.200  0.500  0.500  0.385  0.333
#
#     2S 3B      1B        2B   3B
# 0   0.250  0.2500  0.400000  0.0
# 1   0.188  0.3640  0.600000  0.0
# 2   0.333  0.3448  0.318556  0.0
# 3   0.333  0.6670  0.667000  0.0
# 4   0.118  0.1330  0.000000  0.0
# 5   0.182  0.5000  0.200000  0.0
# 6   0.286  0.5000  0.000000  0.0
# 7   0.200  0.1670  1.000000  0.0
# 8   0.571  0.6000  0.000000  0.0
# 9   0.091  0.1000  0.000000  0.0
# 10  0.286  0.1670  0.318556  0.0

# %% [markdown]
# ## 상대전적에서의 NaN 값은 (해당투수별 전적 타율의 평균값 + KT전 타율) /2로 채워주기. 예를 들어 김인태 선수의 NaN값 --> (두산 전체의 고영표 선수 상대 평균 타율 + 김인태선수의 KT전 타율) /2

# %%
doosan_df5
# Out:
#    상대전적    고영표   쿠에바스  오원석     KT
# 0   정수빈  0.500  0.333  1.0  0.375
# 1   케이브  1.000  0.000  0.0  0.333
# 2   양의지  0.000  0.000  0.0  0.250
# 3   김재환  0.333  0.000  0.0  0.364
# 4   양석환  1.000  0.000  0.0  0.167
# 5   강승호  0.667  0.000  0.0  0.208
# 6   오명진  0.000  0.000  NaN  0.000
# 7   김인태    NaN  0.000  NaN  0.286
# 8   박준영    NaN  0.000  0.0  0.250
# 9   김기연    NaN    NaN  NaN  0.429
# 10  임종성    NaN  0.000  NaN    NaN

# %%
count_cols = ["KT"]
doosan_df5[count_cols] = doosan_df5[count_cols].fillna(doosan_df5[count_cols].mean())
doosan_df5
# Out:
#    상대전적    고영표   쿠에바스  오원석      KT
# 0   정수빈  0.500  0.333  1.0  0.3750
# 1   케이브  1.000  0.000  0.0  0.3330
# 2   양의지  0.000  0.000  0.0  0.2500
# 3   김재환  0.333  0.000  0.0  0.3640
# 4   양석환  1.000  0.000  0.0  0.1670
# 5   강승호  0.667  0.000  0.0  0.2080
# 6   오명진  0.000  0.000  NaN  0.0000
# 7   김인태    NaN  0.000  NaN  0.2860
# 8   박준영    NaN  0.000  0.0  0.2500
# 9   김기연    NaN    NaN  NaN  0.4290
# 10  임종성    NaN  0.000  NaN  0.2662

# %%
타자컬럼 = ['고영표', '쿠에바스', '오원석']
for col in 타자컬럼:
    col_mean = doosan_df5[col].mean()
    def fill_func(row):
        if pd.isna(row[col]):
            return (col_mean + row['KT']) / 2
        else:
            return row[col]
    doosan_df5[col] = doosan_df5.apply(fill_func, axis=1)

doosan_df5
# Out:
#    상대전적     고영표     쿠에바스       오원석      KT
# 0   정수빈  0.5000  0.33300  1.000000  0.3750
# 1   케이브  1.0000  0.00000  0.000000  0.3330
# 2   양의지  0.0000  0.00000  0.000000  0.2500
# 3   김재환  0.3330  0.00000  0.000000  0.3640
# 4   양석환  1.0000  0.00000  0.000000  0.1670
# 5   강승호  0.6670  0.00000  0.000000  0.2080
# 6   오명진  0.0000  0.00000  0.071429  0.0000
# 7   김인태  0.3930  0.00000  0.214429  0.2860
# 8   박준영  0.3750  0.00000  0.000000  0.2500
# 9   김기연  0.4645  0.23115  0.285929  0.4290
# 10  임종성  0.3831  0.00000  0.204529  0.2662

# %%
kt_df5
# Out:
#    상대 전적    최승용  홍민규    콜어빈     두산
# 0    로하스  0.000  NaN  0.666  0.353
# 1    강백호  0.333  NaN    NaN  0.182
# 2    허경민  0.333  NaN    NaN  0.385
# 3    안현민    NaN  0.0  0.333  0.200
# 4    장성우  0.333  NaN  0.000  0.095
# 5    김민혁  0.333  NaN  0.333  0.471
# 6    황재균  0.000  NaN  0.333  0.263
# 7    배정대  0.000  0.0  0.000  0.217
# 8    김상수  1.000  NaN    NaN  0.400
# 9    문상철  0.000  0.0  0.000  0.077
# 10   권동진    NaN  0.0  0.000  0.167

# %%
타자컬럼 = ['최승용', '홍민규', '콜어빈']

for col in 타자컬럼:
    col_mean = kt_df5[col].mean()
    def fill_func(row):
        if pd.isna(row[col]):
            return (col_mean + row['두산']) / 2
        else:
            return row[col]
    kt_df5[col] = kt_df5.apply(fill_func, axis=1)

kt_df5
# Out:
#    상대 전적       최승용     홍민규       콜어빈     두산
# 0    로하스  0.000000  0.1765  0.666000  0.353
# 1    강백호  0.333000  0.0910  0.195062  0.182
# 2    허경민  0.333000  0.1925  0.296563  0.385
# 3    안현민  0.229556  0.0000  0.333000  0.200
# 4    장성우  0.333000  0.0475  0.000000  0.095
# 5    김민혁  0.333000  0.2355  0.333000  0.471
# 6    황재균  0.000000  0.1315  0.333000  0.263
# 7    배정대  0.000000  0.0000  0.000000  0.217
# 8    김상수  1.000000  0.2000  0.304063  0.400
# 9    문상철  0.000000  0.0000  0.000000  0.077
# 10   권동진  0.213056  0.0000  0.000000  0.167

# %% [markdown]
# # Step2. 타순짜기

# %% [markdown]
# ## 종합 데이터와 상대전적을 바탕으로 타순을 짤 예정이므로 2개를 합치기

# %%
doosan_df1 = doosan_df1.rename(columns={'타자 정보': '타자명'})
doosan_df5 = doosan_df5.rename(columns={'상대전적': '타자명'})

# %%
df = pd.merge(doosan_df1, doosan_df5[['타자명', '고영표']], on='타자명', how='left')

# %%
df
# Out:
#     타자명     타율  안타  2루타  3루타  홈런  타점  득점  희생번트  희생플라이  볼넷  삼진    장타율    출루율  \
# 0   정수빈  0.271  42    5    0   2  14  28     2      2  23  15  0.342  0.375
# 1   케이브  0.319  45    7    1   3  22  22     0      3  10  31  0.447  0.361
# 2   양의지  0.329  47    9    0   5  29  20     0      2  21  21  0.497  0.417
# 3   김재환  0.255  35    4    1   5  24  19     0      0  17  34  0.409  0.346
# 4   양석환  0.277  44   10    0   5  22  21     0      3  13  45  0.434  0.341
# 5   강승호  0.224  35   10    2   3  16  23     0      1  14  52  0.372  0.303
# 6   오명진  0.253  23    5    2   1  16  13     0      0   9  20  0.385  0.327
# 7   김인태  0.283  17    4    0   1   8   6     0      0  13  14  0.400  0.411
# 8   박준영  0.227  25    8    0   1  10   9     1      1  10  32  0.327  0.306
# 9   김기연  0.305  18    3    0   1  11   7     2      1   6  14  0.407  0.364
# 10  임종성  0.227   5    1    0   0   2   1     0      0   0   4  0.273  0.227
#
#       OPS     고영표
# 0   0.717  0.5000
# 1   0.808  1.0000
# 2   0.914  0.0000
# 3   0.755  0.3330
# 4   0.775  1.0000
# 5   0.675  0.6670
# 6   0.712  0.0000
# 7   0.811  0.3930
# 8   0.633  0.3750
# 9   0.771  0.4645
# 10  0.500  0.3831

# %% [markdown]
# ## 타율, ops, 상대투수와의 전적을 각각 다른 가중치로 설정해서 1등부터 9등까지 선별 (이 부분을 자유롭게 해주시면 됩니다).

# %%
df['점수'] = (df['타율'] * 0.2) + (df['OPS'] * 0.5) + (df['고영표'] * 0.3)
df_두산타순 = df.sort_values(by='점수', ascending=False)
df_두산타순
# Out:
#     타자명     타율  안타  2루타  3루타  홈런  타점  득점  희생번트  희생플라이  볼넷  삼진    장타율    출루율  \
# 1   케이브  0.319  45    7    1   3  22  22     0      3  10  31  0.447  0.361
# 4   양석환  0.277  44   10    0   5  22  21     0      3  13  45  0.434  0.341
# 9   김기연  0.305  18    3    0   1  11   7     2      1   6  14  0.407  0.364
# 5   강승호  0.224  35   10    2   3  16  23     0      1  14  52  0.372  0.303
# 7   김인태  0.283  17    4    0   1   8   6     0      0  13  14  0.400  0.411
# 0   정수빈  0.271  42    5    0   2  14  28     2      2  23  15  0.342  0.375
# 3   김재환  0.255  35    4    1   5  24  19     0      0  17  34  0.409  0.346
# 2   양의지  0.329  47    9    0   5  29  20     0      2  21  21  0.497  0.417
# 8   박준영  0.227  25    8    0   1  10   9     1      1  10  32  0.327  0.306
# 10  임종성  0.227   5    1    0   0   2   1     0      0   0   4  0.273  0.227
# 6   오명진  0.253  23    5    2   1  16  13     0      0   9  20  0.385  0.327
#
#       OPS     고영표       점수
# 1   0.808  1.0000  0.76780
# 4   0.775  1.0000  0.74290
# 9   0.771  0.4645  0.58585
# 5   0.675  0.6670  0.58240
# 7   0.811  0.3930  0.58000
# 0   0.717  0.5000  0.56270
# 3   0.755  0.3330  0.52840
# 2   0.914  0.0000  0.52280
# 8   0.633  0.3750  0.47440
# 10  0.500  0.3831  0.41033
# 6   0.712  0.0000  0.40660

# %%
df_두산타순.head(9)
# Out:
#    타자명     타율  안타  2루타  3루타  홈런  타점  득점  희생번트  희생플라이  볼넷  삼진    장타율    출루율  \
# 1  케이브  0.319  45    7    1   3  22  22     0      3  10  31  0.447  0.361
# 4  양석환  0.277  44   10    0   5  22  21     0      3  13  45  0.434  0.341
# 9  김기연  0.305  18    3    0   1  11   7     2      1   6  14  0.407  0.364
# 5  강승호  0.224  35   10    2   3  16  23     0      1  14  52  0.372  0.303
# 7  김인태  0.283  17    4    0   1   8   6     0      0  13  14  0.400  0.411
# 0  정수빈  0.271  42    5    0   2  14  28     2      2  23  15  0.342  0.375
# 3  김재환  0.255  35    4    1   5  24  19     0      0  17  34  0.409  0.346
# 2  양의지  0.329  47    9    0   5  29  20     0      2  21  21  0.497  0.417
# 8  박준영  0.227  25    8    0   1  10   9     1      1  10  32  0.327  0.306
#
#      OPS     고영표       점수
# 1  0.808  1.0000  0.76780
# 4  0.775  1.0000  0.74290
# 9  0.771  0.4645  0.58585
# 5  0.675  0.6670  0.58240
# 7  0.811  0.3930  0.58000
# 0  0.717  0.5000  0.56270
# 3  0.755  0.3330  0.52840
# 2  0.914  0.0000  0.52280
# 8  0.633  0.3750  0.47440

# %%
kt_df1 = kt_df1.rename(columns={'타자 정보': '타자명'})
kt_df5 = kt_df5.rename(columns={'상대 전적': '타자명'})

# %%
df = pd.merge(kt_df1, kt_df5[['타자명', '최승용']], on='타자명', how='left')

# %%
df
# Out:
#     타자명     타율  안타  2루타  3루타  홈런  타점  득점  희생번트  희생플라이  볼넷  삼진    장타율    출루율  \
# 0   로하스  0.237  37    8    0   6  18  25     0      2  32  40  0.404  0.366
# 1   강백호  0.227  29    6    0   6  16  12     0      0  12  26  0.414  0.298
# 2   허경민  0.301  31    2    0   1   8   9     0      1  11  12  0.350  0.371
# 3   안현민  0.370  20    4    1   6  17  10     0      0   4  10  0.815  0.433
# 4   장성우  0.208  27    4    0   4  19  12     1      4  21  34  0.331  0.310
# 5   김민혁  0.329  54    6    1   0  11  21     0      1   6  14  0.378  0.358
# 6   황재균  0.256  34    5    0   1  13  13     0      1  14  30  0.316  0.329
# 7   배정대  0.184  21    5    2   1  12   6     4      2   5  33  0.289  0.234
# 8   김상수  0.206  12    3    0   1   3   7     0      0  14   6  0.302  0.351
# 9   문상철  0.227  22    3    1   1   5   7     0      1  10  24  0.309  0.303
# 10  권동진  0.317  26    3    1   0   7  10     2      1  11  26  0.378  0.394
#
#       OPS       최승용
# 0   0.770  0.000000
# 1   0.712  0.333000
# 2   0.721  0.333000
# 3   1.248  0.229556
# 4   0.641  0.333000
# 5   0.736  0.333000
# 6   0.645  0.000000
# 7   0.523  0.000000
# 8   0.653  1.000000
# 9   0.602  0.000000
# 10  0.772  0.213056

# %%
df['점수'] = (df['타율'] * 0.2) + (df['OPS'] * 0.5) + (df['최승용'] * 0.3)
df_KT타순 = df.sort_values(by='점수', ascending=False)
df_KT타순
# Out:
#     타자명     타율  안타  2루타  3루타  홈런  타점  득점  희생번트  희생플라이  볼넷  삼진    장타율    출루율  \
# 3   안현민  0.370  20    4    1   6  17  10     0      0   4  10  0.815  0.433
# 8   김상수  0.206  12    3    0   1   3   7     0      0  14   6  0.302  0.351
# 5   김민혁  0.329  54    6    1   0  11  21     0      1   6  14  0.378  0.358
# 2   허경민  0.301  31    2    0   1   8   9     0      1  11  12  0.350  0.371
# 10  권동진  0.317  26    3    1   0   7  10     2      1  11  26  0.378  0.394
# 1   강백호  0.227  29    6    0   6  16  12     0      0  12  26  0.414  0.298
# 4   장성우  0.208  27    4    0   4  19  12     1      4  21  34  0.331  0.310
# 0   로하스  0.237  37    8    0   6  18  25     0      2  32  40  0.404  0.366
# 6   황재균  0.256  34    5    0   1  13  13     0      1  14  30  0.316  0.329
# 9   문상철  0.227  22    3    1   1   5   7     0      1  10  24  0.309  0.303
# 7   배정대  0.184  21    5    2   1  12   6     4      2   5  33  0.289  0.234
#
#       OPS       최승용        점수
# 3   1.248  0.229556  0.766867
# 8   0.653  1.000000  0.667700
# 5   0.736  0.333000  0.533700
# 2   0.721  0.333000  0.520600
# 10  0.772  0.213056  0.513317
# 1   0.712  0.333000  0.501300
# 4   0.641  0.333000  0.462000
# 0   0.770  0.000000  0.432400
# 6   0.645  0.000000  0.373700
# 9   0.602  0.000000  0.346400
# 7   0.523  0.000000  0.298300

# %%
df_KT타순.head(9)
# Out:
#     타자명     타율  안타  2루타  3루타  홈런  타점  득점  희생번트  희생플라이  볼넷  삼진    장타율    출루율  \
# 3   안현민  0.370  20    4    1   6  17  10     0      0   4  10  0.815  0.433
# 8   김상수  0.206  12    3    0   1   3   7     0      0  14   6  0.302  0.351
# 5   김민혁  0.329  54    6    1   0  11  21     0      1   6  14  0.378  0.358
# 2   허경민  0.301  31    2    0   1   8   9     0      1  11  12  0.350  0.371
# 10  권동진  0.317  26    3    1   0   7  10     2      1  11  26  0.378  0.394
# 1   강백호  0.227  29    6    0   6  16  12     0      0  12  26  0.414  0.298
# 4   장성우  0.208  27    4    0   4  19  12     1      4  21  34  0.331  0.310
# 0   로하스  0.237  37    8    0   6  18  25     0      2  32  40  0.404  0.366
# 6   황재균  0.256  34    5    0   1  13  13     0      1  14  30  0.316  0.329
#
#       OPS       최승용        점수
# 3   1.248  0.229556  0.766867
# 8   0.653  1.000000  0.667700
# 5   0.736  0.333000  0.533700
# 2   0.721  0.333000  0.520600
# 10  0.772  0.213056  0.513317
# 1   0.712  0.333000  0.501300
# 4   0.641  0.333000  0.462000
# 0   0.770  0.000000  0.432400
# 6   0.645  0.000000  0.373700

# %% [markdown]
# # Step3. 경기 예측하기

# %% [markdown]
# ## 5개의 데이터를 종합적으로 사용할 예정이므로 1개로 합치기

# %%
doosan_df1 = doosan_df1.rename(columns={'타자 정보': '타자명'})
doosan_df2 = doosan_df2.rename(columns={'아웃카운트에 따른 타율': '타자명'})
doosan_df3 = doosan_df3.rename(columns={'주자 위치에 따른 타율': '타자명'})
doosan_df4 = doosan_df4.rename(columns={'카운트에 따른 타자 타율': '타자명'})
doosan_df5 = doosan_df5.rename(columns={'상대전적': '타자명'})

# %%
kt_df1 = kt_df1.rename(columns={'타자 정보': '타자명'})
kt_df2 = kt_df2.rename(columns={'아웃카운트에 따른 타율': '타자명'})
kt_df3 = kt_df3.rename(columns={'주자 위치에 따른 타율': '타자명'})
kt_df4 = kt_df4.rename(columns={'카운트에 따른 타자 타율': '타자명'})
kt_df5 = kt_df5.rename(columns={'상대전적': '타자명'})

# %%
merge_keys = ['타자명']

doosan_merged = doosan_df1.merge(doosan_df2, on=merge_keys, how='left') \
                           .merge(doosan_df3, on=merge_keys, how='left') \
                           .merge(doosan_df4, on=merge_keys, how='left')

# %%
doosan_merged
# Out:
#     타자명     타율  안타  2루타  3루타  홈런  타점  득점  희생번트  희생플라이  ...     2S   1S 1B  \
# 0   정수빈  0.271  42    5    0   2  14  28     2      2  ...  0.214  0.3000
# 1   케이브  0.319  45    7    1   3  22  22     0      3  ...  0.083  0.3850
# 2   양의지  0.329  47    9    0   5  29  20     0      2  ...  0.364  0.3330
# 3   김재환  0.255  35    4    1   5  24  19     0      0  ...  0.231  0.3330
# 4   양석환  0.277  44   10    0   5  22  21     0      3  ...  0.250  0.4290
# 5   강승호  0.224  35   10    2   3  16  23     0      1  ...  0.143  0.4290
# 6   오명진  0.253  23    5    2   1  16  13     0      0  ...  0.167  0.2000
# 7   김인태  0.283  17    4    0   1   8   6     0      0  ...  0.000  0.0000
# 8   박준영  0.227  25    8    0   1  10   9     1      1  ...  0.250  0.4290
# 9   김기연  0.305  18    3    0   1  11   7     2      1  ...  0.143  0.4000
# 10  임종성  0.227   5    1    0   0   2   1     0      0  ...  0.000  0.3238
#
#     1S 2B     1S 3B  2S 1B  2S 2B  2S 3B     1B      2B  3B
# 0   0.333  0.857000  0.200  0.188  0.214  0.500  0.0000 NaN
# 1   0.167  1.000000  0.250  0.333  0.167  0.313  0.4290 NaN
# 2   0.333  0.500000  0.222  0.240  0.308  0.214  0.6670 NaN
# 3   0.167  0.250000  0.083  0.042  0.375  0.571  0.3330 NaN
# 4   0.286  0.333000  0.156  0.281  0.278  0.143  0.0000 NaN
# 5   0.500  0.500000  0.077  0.103  0.111  0.583  0.0000 NaN
# 6   0.000  0.604444  0.077  0.222  0.400  0.273  0.0000 NaN
# 7   0.000  1.000000  0.250  0.375  0.667  0.000  1.0000 NaN
# 8   0.167  0.000000  0.080  0.316  0.375  0.000  0.5000 NaN
# 9   0.400  1.000000  0.000  0.333  0.667  0.200  0.5000 NaN
# 10  0.500  0.604444  0.000  0.600  0.000  0.000  0.3429 NaN
#
# [11 rows x 37 columns]

# %%
kt_merged = kt_df1.merge(kt_df2, on=merge_keys, how='left') \
                  .merge(kt_df3, on=merge_keys, how='left') \
                  .merge(kt_df4, on=merge_keys, how='left')

# %%
kt_merged
# Out:
#     타자명     타율  안타  2루타  3루타  홈런  타점  득점  희생번트  희생플라이  ...     2S  1S 1B  \
# 0   로하스  0.237  37    8    0   6  18  25     0      2  ...  0.000  0.714
# 1   강백호  0.227  29    6    0   6  16  12     0      0  ...  0.158  0.267
# 2   허경민  0.301  31    2    0   1   8   9     0      1  ...  0.158  0.300
# 3   안현민  0.370  20    4    1   6  17  10     0      0  ...  0.333  0.300
# 4   장성우  0.208  27    4    0   4  19  12     1      4  ...  0.125  0.286
# 5   김민혁  0.329  54    6    1   0  11  21     0      1  ...  0.143  0.300
# 6   황재균  0.256  34    5    0   1  13  13     0      1  ...  0.154  0.500
# 7   배정대  0.184  21    5    2   1  12   6     4      2  ...  0.000  0.333
# 8   김상수  0.206  12    3    0   1   3   7     0      0  ...  0.000  0.077
# 9   문상철  0.227  22    3    1   1   5   7     0      1  ...  0.357  0.333
# 10  권동진  0.317  26    3    1   0   7  10     2      1  ...  0.182  0.200
#
#     1S 2B  1S 3B  2S 1B  2S 2B  2S 3B      1B        2B   3B
# 0   0.600  0.000  0.172  0.231  0.250  0.2500  0.400000  0.0
# 1   0.286  0.500  0.056  0.167  0.188  0.3640  0.600000  0.0
# 2   0.500  0.200  0.375  0.400  0.333  0.3448  0.318556  0.0
# 3   1.000  0.400  0.400  0.000  0.333  0.6670  0.667000  0.0
# 4   0.333  0.250  0.120  0.267  0.118  0.1330  0.000000  0.0
# 5   0.438  0.286  0.360  0.400  0.182  0.5000  0.200000  0.0
# 6   0.417  0.000  0.214  0.182  0.286  0.5000  0.000000  0.0
# 7   0.429  0.000  0.059  0.053  0.200  0.1670  1.000000  0.0
# 8   0.500  0.000  0.200  0.250  0.571  0.6000  0.000000  0.0
# 9   0.125  0.333  0.077  0.167  0.091  0.1000  0.000000  0.0
# 10  0.500  0.500  0.385  0.333  0.286  0.1670  0.318556  0.0
#
# [11 rows x 37 columns]

# %% [markdown]
# ## 타자별 데이터를 활용해서 선수 개별 안타 확률을 생성하는 함수

# %%
def compute_player_hit_probs(df):

    # 타율과 OPS의 최소, 최대 값 계산합니다.
    avg_min, avg_max = df['타율'].min(), df['타율'].max()
    ops_min, ops_max = df['OPS'].min(), df['OPS'].max()

    player_probs = {}

    for idx, row in df.iterrows():
        pa = estimate_at_bats(row)
        total_hits = row['안타']

        if pa == 0 or total_hits == 0 or pd.isna(row['타율']) or pd.isna(row['OPS']):
            probs = {'1B': 0, '2B': 0, '3B': 0, 'HR': 0, 'OUT': 1.0}
            
        else:
            avg_range = max(0.001, avg_max - avg_min)
            ops_range = max(0.001, ops_max - ops_min)

            avg_norm = (row['타율'] - avg_min) / avg_range
            ops_norm = (row['OPS'] - ops_min) / ops_range

            # 선수별 안타칠 확률을 계산합니다. (0.1~0.35 사이로 설정)
            # 이 값들을 자유롭게 변경하셔서 실제 결과와 비슷한 parameter가 무엇일지 찾아보면 좋을 것 같습니다!
            
            #1. 상황별 데이터를 활용해서 다양한 상황 속에서 타자가 안타 칠 확률을 계산합니다.
            out_weights = ['0아웃', '1아웃', '2아웃']
            
            #(득점권 상황)
            runner_weights = ['만루', '2루,3루', '1루,3루', '1루,2루']
            
            #(현대 야구에서 가장 많은 타격이 일어나는 카운트)
            count_weights = ['2S 3B', '2S 2B', '2S 1B', '1S 1B', '1S 2B', '1S 3B']

            out_weight = np.mean([row.get(ow, 0.25) for ow in out_weights])
            runner_weight = np.mean([row.get(rw, 0.25) for rw in runner_weights])
            count_weight = np.mean([row.get(cw, 0.25) for cw in count_weights])
            
            # 저는 안타칠 확률을 타자의 기본 데이터 + 상황별 데이터의 합으로 계산했습니다.
            
            # 기본데이터를 활용한 확률 (타율과 OPS를 각각 0.4, 0.6 가중치를 두었습니다.)
            base_hit_prob = 0.1 + 0.2 * (0.4 * avg_norm + 0.6 * ops_norm)
            
            # 상황별 데이터를 활용한 확률 (각각 0,2, 0,5, 0,3 가중치를 두었습니다.)
            situational_factor = 0.05 * (0.2 * out_weight + 0.5 * runner_weight + 0.3 * count_weight) / 3  
            prob_hit = min(0.35, base_hit_prob + situational_factor)
            prob_out = 1 - prob_hit

            # 각 선수별 안타, 2루타, 3루타, 홈런칠 확률 생성합니다. (이것도 0.01, 0.005 숫자를 자유롭게 변경 하시면 됩니다.)
            prob_1B = max(0.01, row['1B'] / total_hits)
            prob_2B = max(0.005, row['2B'] / total_hits)
            prob_3B = max(0.002, row['3B'] / total_hits)
            prob_HR = max(0.005, row['홈런'] / total_hits)

            total_ratio = prob_1B + prob_2B + prob_3B + prob_HR
            prob_1B /= total_ratio
            prob_2B /= total_ratio
            prob_3B /= total_ratio
            prob_HR /= total_ratio
            
            probs = {
                '1B': prob_hit * prob_1B,
                '2B': prob_hit * prob_2B,
                '3B': prob_hit * prob_3B,
                'HR': prob_hit * prob_HR,
                'OUT': prob_out
            }

            total_prob = sum(probs.values())
            if total_prob > 0:
                for k in probs:
                    probs[k] /= total_prob

        player_probs[row['타자명']] = probs

    return player_probs

# %% [markdown]
# ## 타자의 전체 타수를 계산하는 함수

# %%
def estimate_at_bats(row):
    sac = row.get('희생번트', 0)
    sf = row.get('희생플라이', 0)
    if row['타율'] > 0:
        est_pa = row['안타'] / row['타율']
    else:
        est_pa = 100 
    est_pa -= sac + sf
    return max(1, est_pa)

# %% [markdown]
# ## 각 타자의 경기에서의 타석 결과를 simulation 하는 함수

# %%
def simulate_at_bat(player_name, player_probs):
    probs = player_probs[player_name]
    return random.choices(list(probs.keys()), weights=list(probs.values()), k=1)[0]

# %% [markdown]
# ## 각각의 타석 결과에 따라 베이스 현황을 최신화 및 점수 득점 경로 제시하는 함수

# %%
def update_bases(base_state, result):
    runs = 0
    new_bases = [0, 0, 0]

    if result == 'OUT':
        return base_state, runs

    if result == 'HR':
        runs = sum(base_state) + 1
        return [0, 0, 0], runs

    if result == '1B':
        runs += base_state[2]
        new_bases[2] = base_state[1]
        new_bases[1] = base_state[0]
        new_bases[0] = 1
    elif result == '2B':
        runs += base_state[2] + base_state[1]
        new_bases[2] = base_state[0]
        new_bases[1] = 1
    elif result == '3B':
        runs += sum(base_state)
        new_bases[2] = 1

    return new_bases, runs

# %% [markdown]
# ## 각각의 공격을 simulation하는 함수 (예를 들어 두산 1회초, kt 3회말 공격 양상 예측)

# %%
def simulate_half_inning(lineup, player_probs, start_idx):
    outs = 0
    bases = [0, 0, 0]
    score = 0
    batter_idx = start_idx
    batter_stats = {name: {'타수': 0, '안타': 0} for name in lineup}

    while outs < 3:
        batter = lineup[batter_idx % len(lineup)]
        result = simulate_at_bat(batter, player_probs)
        batter_stats[batter]['타수'] += 1
        if result != 'OUT':
            batter_stats[batter]['안타'] += 1
        bases, runs = update_bases(bases, result)
        score += runs
        if result == 'OUT':
            outs += 1
        batter_idx += 1

    return score, batter_idx, batter_stats

# %% [markdown]
# ## 위에 제시된 함수를 1회부터 9회까지 반복하기

# %%
def simulate_game(away_lineup, away_probs, home_lineup, home_probs):
    away_idx, home_idx = 0, 0
    away_scores, home_scores = [], []
    away_stats_total = {name: {'타수': 0, '안타': 0} for name in away_lineup}
    home_stats_total = {name: {'타수': 0, '안타': 0} for name in home_lineup}

    for inning in range(9):
        away_score, away_idx, away_stats = simulate_half_inning(away_lineup, away_probs, away_idx)
        for name in away_stats:
            away_stats_total[name]['타수'] += away_stats[name]['타수']
            away_stats_total[name]['안타'] += away_stats[name]['안타']
        away_scores.append(away_score)

        # 홈팀이 이기고 있는경우, 9회말은 진행하지 않습니다.
        
        if inning == 8 and sum(home_scores) > sum(away_scores):
            break

        home_score, home_idx, home_stats = simulate_half_inning(home_lineup, home_probs, home_idx)
        for name in home_stats:
            home_stats_total[name]['타수'] += home_stats[name]['타수']
            home_stats_total[name]['안타'] += home_stats[name]['안타']
        home_scores.append(home_score)

    return {
        'away_total': sum(away_scores),
        'home_total': sum(home_scores),
        'away_inning_scores': away_scores,
        'home_inning_scores': home_scores,
        'away_stats': away_stats_total,
        'home_stats': home_stats_total
    }

# %% [markdown]
# ## 이닝별 득점을 나타내는 그래프 구현 함수

# %%
def plot_inning_scores(team_name, scores):
    innings = list(range(1, len(scores)+1))
    plt.plot(innings, scores, marker='o', label=team_name)
    plt.xticks(range(1, 10))
    plt.xlabel("이닝")
    plt.ylabel("득점")
    plt.title("이닝별 득점")
    plt.legend()
    plt.grid(True)

# %% [markdown]
# ## 앞에서 구한 9명의 타자를 바탕으로 라인업을 구성하기

# %%
doosan_lineup = ['케이브', '양석환', '김기연', '강승호', '김인태', '정수빈', '김재환', '양의지', '박준영']
kt_lineup = ['안현민', '김상수', '김민혁', '허경민', '권동진', '강백호', '장성우', '로하스', '황재균']

# %%
doosan_player_probs = compute_player_hit_probs(doosan_merged)
kt_player_probs = compute_player_hit_probs(kt_merged)

# %%
result = simulate_game(
    away_lineup=doosan_lineup,
    away_probs=doosan_player_probs,
    home_lineup=kt_lineup,
    home_probs=kt_player_probs
)

# %%
print(f"두산(원정): {result['away_total']}점")
print(f"KT(홈): {result['home_total']}점")
# Out:
# 두산(원정): 5점
# KT(홈): 4점

# %%
plt.figure(figsize=(10, 5))
plot_inning_scores("두산 (원정)", result['away_inning_scores'])
plot_inning_scores("KT (홈)", result['home_inning_scores'])
plt.show()

# %% [markdown]
# ## 타자별 하루 결과를 나타내는 함수

# %%
def print_player_stats(team_name, stats_dict):
    print(f"\n📊 {team_name} 타자 성적")
    print("-" * 30)
    for player, stats in stats_dict.items():
        ab = stats['타수']
        hits = stats['안타']
        avg = hits / ab if ab > 0 else 0
        print(f"{player}: {ab}타수 {hits}안타 ({avg:.3f})")

# %%
print_player_stats("두산", result['away_stats'])
print_player_stats("KT", result['home_stats'])
# Out:
# 📊 두산 타자 성적
# ------------------------------
# 케이브: 4타수 2안타 (0.500)
# 양석환: 4타수 0안타 (0.000)
# 김기연: 4타수 0안타 (0.000)
# 강승호: 4타수 1안타 (0.250)
# 김인태: 4타수 0안타 (0.000)
# 정수빈: 4타수 1안타 (0.250)
# 김재환: 3타수 1안타 (0.333)
# 양의지: 3타수 1안타 (0.333)
# 박준영: 3타수 0안타 (0.000)
#
# 📊 KT 타자 성적
# ------------------------------
# 안현민: 4타수 2안타 (0.500)
# 김상수: 4타수 2안타 (0.500)
# 김민혁: 4타수 0안타 (0.000)
# 허경민: 4타수 1안타 (0.250)
# 권동진: 4타수 0안타 (0.000)
# 강백호: 4타수 1안타 (0.250)
# 장성우: 4타수 0안타 (0.000)
# 로하스: 3타수 0안타 (0.000)
# 황재균: 3타수 1안타 (0.333)

# %%
def simulate_game_monte_carlo(n_simulations, away_lineup, away_probs, home_lineup, home_probs):
    results = []
    for _ in range(n_simulations):
        game_result = simulate_game(away_lineup, away_probs, home_lineup, home_probs)
        results.append(game_result)
    return results

# %%
def summarize_results(results):
    away_total = [r['away_total'] for r in results]
    home_total = [r['home_total'] for r in results]
    print(f"평균 점수 (AWAY): {sum(away_total)/len(away_total):.2f}")
    print(f"평균 점수 (HOME): {sum(home_total)/len(home_total):.2f}")
    print(f"승률 (AWAY): {sum(1 for i in range(len(results)) if away_total[i] > home_total[i]) / len(results):.2%}")
    print(f"승률 (HOME): {sum(1 for i in range(len(results)) if home_total[i] > away_total[i]) / len(results):.2%}")

# %%
doosan_probs = compute_player_hit_probs(doosan_merged)
kt_probs = compute_player_hit_probs(kt_merged)

# %%
monte_results = simulate_game_monte_carlo(
    n_simulations=200,
    away_lineup=doosan_lineup,
    away_probs=doosan_probs,
    home_lineup=kt_lineup,
    home_probs=kt_probs
)

# %%
summarize_results(monte_results)
# Out:
# 평균 점수 (AWAY): 6.05
# 평균 점수 (HOME): 4.14
# 승률 (AWAY): 62.50%
# 승률 (HOME): 25.00%
